# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#03112A;font-size:250%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;text-align: center;color:white; border-radius: 20px; padding-top: 20px; padding-bottom: 20px;"><b><b><span style='color:#2ae4f5''></span></b> Exercise no. 6  </b></p>
# </div>

# %% [markdown]
# ## 📚 Functions & Operations Overview
#
# ### 🔹 **Data Manipulation**
# - **Groupby**: Groups data based on one or more keys to perform aggregate calculations.
# - **Apply**: Applies a function along an axis of the DataFrame (rows or columns).
# - **Agg**: Allows multiple aggregation operations (mean, sum, etc.) simultaneously on grouped data.
# - **Lambda**: Defines short, inline functions for quick, concise transformations.
# - **reset_index()**: Adds or resets a numerical index to the DataFrame.
#
# ### 🔹 **Encoding Techniques**
# - **One-Hot Encoding**: Converts categorical variables into binary indicator (dummy) variables.
# - **Label Encoding**: Encodes categorical variables as numerical values to simplify analysis.
#
# ### 🔹 **Datetime Operations**
# - **pd.to_datetime(df['date'])**: Converts a column into datetime data type.
# - **pd.DatetimeIndex(df['date']).month**: Extracts the month component from datetime attributes.
#
# ### 📊 **Visualization**
# - **boxplot**: Displays distribution, central tendency, and outliers.
# - **histplot**: Shows frequency distributions of numerical data.
# - **scatterplot**: Visualizes relationships between two numerical variables.
# - **stripplot**: Plots data points for categorical data to show distribution and spread.
# - **barplot**: Compares categorical data based on aggregate values.
# - **countplot**: Shows counts of observations in categorical bins.
# - **FacetGrid**: Creates a grid of plots to visualize subsets of data easily.
# - **pairplot**: Visualizes pairwise relationships among multiple numerical variables.

# %% [markdown]
# ---
# ## 🎯 **Today's Tutorial Objectives**
#
# In this session, we will apply practical techniques of **Exploratory Data Analysis (EDA)** on marketing analytics data. Our focus areas include:
#
# ### 🛠 **Fixing Problems**
# - Identify and resolve basic data quality issues.
#
# ### 🔍 **Data Understanding**
# - **Numeric Data**: Exploring numerical variables and their distributions.
# - **Binary Data**: Handling and interpreting binary categorical variables.
# - **Categorical Data**: Exploring categories, frequency, and encoding methods.
#
# ### 📌 **Data Preparation**
# - **Missing Values**: Detect and manage missing data points effectively.
# - **Outliers**: Identify and treat anomalies in data.
# - **Transformations**: Apply necessary transformations to data features.
#
# ### 📈 **Correlations & Observations**
# - Explore correlations to identify insights and understand feature relationships.
# ---

# %% [markdown]
# <h5 style="font-size:50px;color:#1db6f5;text-align:left"><strong>The Cheat</strong> <strong style="color:black">Sheet:</strong></h5>
#
# <p style="font-size:120%">The below cheatsheet can be used as a reference to keep in mind what visualizations we can use.</p>
#
# <img src="https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F1688884%2Fb4372f0e806b6f75c7b56904b1159a68%2FData%20Visualization%20Cheatsheet.jpg?generation=1592767560257939&alt=media"></img>

# %% [markdown]
# ## <b id="import-libraries">Importing </b> <b style='color:#1db6f5'>Libraries</b>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import HTML,display

# %% [markdown]
# ## <b id="import-libraries">Importing </b> <b style='color:#1db6f5'>Data</b>

# %%
url_list = ['https://raw.githubusercontent.com/Razelbaz1/exercises-package/refs/heads/master/data/data_parts_super_store/part_1.csv',
           'https://raw.githubusercontent.com/Razelbaz1/exercises-package/refs/heads/master/data/data_parts_super_store/part_2.csv']

df = pd.concat([pd.read_csv(url, encoding='latin1') for url in url_list], ignore_index=True)

# %% [markdown]
# ## <b id="import-libraries">Basic </b> <b style='color:#1db6f5'>EDA</b>

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   float64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# # <b id='dist-num-cols'>Distribution of </b> <b style='color:#1db6f5'> Numerical columns</b>

# %% [markdown]
# <h2 style='color:#1db6f5'><b> Histplot:<b></h2>
# <h3> A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within disrete bins. </h3>

# %% [markdown]
# <h2 style='color:#1db6f5'><b> Boxplot:<b></h2>
# <h3> A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”). It can tell you about your outliers and what their values are. </h3>

# %% [markdown]
# <h2 style='color:#1db6f5'><b> Kdeplot:<b></h2>
# <h3>A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.
#  </h3>

# %%
imp_numerical_cols=['Sales','Profit','Quantity','Discount']
for i,col in enumerate(imp_numerical_cols):
    text="<center><h3><b  style='color:black'>" + f"Distribution of</b> <b style='color:#1db6f5'> {col}"+ "</b></h3><hr></center>"
    display(HTML(text))
    plt.figure(figsize=(16,5))
    bins='auto'
    if i in [0,1]:
        bins=25
    plt.subplot(1,3,1)
    sns.histplot(data=df,x=col,stat='density',bins=bins,color='#a2d9ce')
    plt.title(f'Histogram of {col}',size=15)
    
    plt.subplot(1,3,2)
    sns.kdeplot(data=df,x=col,color='#3498db')
    plt.title(f'kdeplot of {col}',size=15)
    
    plt.subplot(1,3,3)
    sns.boxplot(data=df,x=col,color='#fad7a0')
    plt.title(f'Box-plot of {col}',size=15)
    plt.tight_layout()
    plt.show()
# Out:
# <center><h3><b  style='color:black'>Distribution of</b> <b style='color:#1db6f5'> Sales</b></h3><hr></center>
# <center><h3><b  style='color:black'>Distribution of</b> <b style='color:#1db6f5'> Profit</b></h3><hr></center>
# <center><h3><b  style='color:black'>Distribution of</b> <b style='color:#1db6f5'> Quantity</b></h3><hr></center>
# <center><h3><b  style='color:black'>Distribution of</b> <b style='color:#1db6f5'> Discount</b></h3><hr></center>

# %% [markdown]
# ---
# # <b id='dist-num-cols'>Detect </b> <b style='color:#1db6f5'> outliers</b>

# %%
# Analyze outlier values in the 'Sales' variable

# Calculate the first and third quartiles (Q1 and Q3)
Q1_sales = df['Sales'].quantile(0.25)
Q3_sales = df['Sales'].quantile(0.75)
IQR_sales = Q3_sales - Q1_sales  # Interquartile Range

# Define boundaries to detect outliers
lower_bound_sales = Q1_sales - 1.5 * IQR_sales
upper_bound_sales = Q3_sales + 1.5 * IQR_sales

# Filter the outlier values
outliers_sales = df[(df['Sales'] < lower_bound_sales) | (df['Sales'] > upper_bound_sales)]

# Display a summary of detected outliers
outliers_summary = {
    'Total rows': df.shape[0],
    'Outliers detected': outliers_sales.shape[0],
    'Outlier percentage': round(100 * outliers_sales.shape[0] / df.shape[0], 2),
    'Minimum sales among outliers': outliers_sales['Sales'].min(),
    'Maximum sales among outliers': outliers_sales['Sales'].max()
}

outliers_summary
# Out:
# {'Total rows': 9994,
#  'Outliers detected': 1167,
#  'Outlier percentage': 11.68,
#  'Minimum sales among outliers': np.float64(499.168),
#  'Maximum sales among outliers': np.float64(22638.48)}

# %%
# Add an indicator column for outlier detection
df['is_outlier_sales'] = (df['Sales'] < lower_bound_sales) | (df['Sales'] > upper_bound_sales)

# Filter only the outlier records
outlier_sales_df = df[df['is_outlier_sales']]

# Analyze: classify outliers by category and check if the profit is negative
category_outlier_analysis = (
    outlier_sales_df
    .assign(Negative_Profit = outlier_sales_df['Profit'] < 0)  # Create a boolean column for negative profits
    .groupby('Category')
    .agg(
        Total_Outliers=('Sales', 'count'),  # Count total outliers per category
        Outliers_with_Negative_Profit=('Negative_Profit', 'sum'),  # Count how many have negative profit
        Percentage_Negative_Profit=('Negative_Profit', lambda x: round(100 * x.sum() / x.count(), 2))  # Calculate percentage
    )
    .reset_index()
)

category_outlier_analysis
# Out:
#           Category  Total_Outliers  Outliers_with_Negative_Profit  \
# 0        Furniture             467                            164
# 1  Office Supplies             300                             49
# 2       Technology             400                             46
#
#    Percentage_Negative_Profit
# 0                       35.12
# 1                       16.33
# 2                       11.50

# %% [markdown]
# ## 📊 Insights from Outlier Analysis
#
# - In the **Furniture** category, a significant portion of high-sales transactions resulted in negative profits (**35.12%**).
# - In **Office Supplies**, the rate of negative profit among outlier sales is more moderate (**16.33%**).
# - In **Technology**, only a small portion (**11.5%**) of high-sales transactions resulted in losses.
#
# ### 🧠 Interpretation:
# - High-ticket items in the Furniture category often lead to losses, potentially due to high logistics costs, aggressive discounts, or suboptimal pricing strategies.
# - Office Supplies and Technology sectors are relatively more profitable even among large transactions.

# %%
outlier_sales_df['Profit'] < 0
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Name: Profit, Length: 1167, dtype: bool

# %%
# Analyze sub-categories among outlier sales
subcategory_outlier_analysis = (
    outlier_sales_df
    .assign(Negative_Profit = outlier_sales_df['Profit'] < 0)
    .groupby('Sub-Category')
    .agg(
        Total_Outliers=('Sales', 'count'),
        Outliers_with_Negative_Profit=('Negative_Profit', 'sum'),
        Percentage_Negative_Profit=('Negative_Profit', lambda x: round(100 * x.sum() / x.count(), 2)),
        Average_Profit=('Profit', 'mean')
    )
    .sort_values(by='Percentage_Negative_Profit', ascending=False)
    .reset_index()
)

subcategory_outlier_analysis
# Out:
#    Sub-Category  Total_Outliers  Outliers_with_Negative_Profit  \
# 0        Tables             146                             75
# 1      Supplies              14                              6
# 2     Bookcases              63                             25
# 3      Machines              65                             22
# 4        Chairs             227                             60
# 5       Binders              80                             20
# 6       Storage             142                             23
# 7   Furnishings              31                              4
# 8        Phones             210                             21
# 9   Accessories              69                              3
# 10   Appliances              56                              0
# 11          Art               1                              0
# 12    Envelopes               1                              0
# 13      Copiers              56                              0
# ...

# %% [markdown]
# ## 🧠 Student Discussion: Choosing the Right Graph
#
# We have just analyzed sub-categories with high sales and checked if these sales lead to losses.
# Now, before we move on:
#
# 👉 **Question for you:**
# > Based on the table we generated, what type of graph would you choose to best visualize:
# > - The percentage of negative profits per sub-category?
# > - The average profit per sub-category?
# >
# > Think about what would make it easiest to compare between sub-categories!

# %% [markdown]
# ---
# <div dir="rtl">
#
# ## 📚 מסקנות:
#
# - תתי-הקטגוריות הבעייתיות ביותר הן **Tables** ו־**Supplies**, שבהן שיעור גדול מהמכירות הגבוהות הסתיימו בהפסד.
# - בקטגוריית **Tables** מעל 50% מהמכירות החריגות הובילו לרווח שלילי.
# - הרווח הממוצע בתתי-קטגוריות אלה שלילי או נמוך במיוחד.
# - תתי-קטגוריות אחרות כמו **Copiers** ו־**Appliances** דווקא מציגות רווחים חיוביים וגבוהים בעסקאות גדולות.
# - המשמעות: יש צורך לבחון מחדש את מדיניות המחירים, ההנחות או מבנה העלויות בפריטים כמו שולחנות וציוד משרדי מסוים.
#
# ---

# %% [markdown]
# ## Ans:

# %% [markdown]
# - **Barplot** for the **Percentage of Negative Profits** per sub-category.
# - **Barplot** for the **Average Profit** per sub-category.
# - **Optional:** A **Heatmap** (correlation or color scale) if we want a more compact visual comparison.
#
# Each of these graphs can highlight where the main issues are and make trends easier to spot!
#
# ---

# %% [markdown]
# ## ✅ Suggested Visualizations:

# %%
# Set a consistent style
sns.set(style="whitegrid")
# Heatmap – Both metrics
heatmap_data = sorted_df.set_index('Sub-Category')[['Percentage_Negative_Profit', 'Average_Profit']]

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='RdYlBu', fmt=".1f")
plt.title('Heatmap of Profit Metrics per Sub-Category (Outlier Sales)', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Taking a subset of data (To keep things simple)
df_stackb = df[['Ship Mode','Sales','Profit']]
# taking a groupby on category and then ship mode...
df_stackb = df_stackb.groupby(['Ship Mode']).sum().reset_index()

# Visualizing the Stacked BarChart
plt.figure(figsize=[10,15])
plt.subplot(3,1,1)
plt.bar(x=df_stackb['Ship Mode'], height=df_stackb['Sales'], color='#F05454')
plt.bar(x=df_stackb['Ship Mode'], height=df_stackb['Profit'], bottom=df_stackb['Sales'], color='#30475E')
plt.title("Sales & Profit Across Ship Modes", size=20, pad=20)
plt.legend(['Sales','Profit'])

###################################################################
# Taking a subset of data (To keep things simple)
df_pie = df[['Category','Sales','Profit']]
# taking a groupby on category and then ship mode...
df_pie = df_pie.groupby(['Category']).sum().reset_index()

# Visualizing the Pie Chart (Profit)
plt.subplot(3,2,3)
plt.pie(df_pie['Profit'], labels=df_pie['Category'], colors=['#F05454','#30475E','#222831','#DDDDDD'])
plt.title("Composition of Category for Profit")

# Visualizing the Pie Chart (Sales)
plt.subplot(3,2,4)
plt.pie(df_pie['Sales'], labels=df_pie['Category'], colors=['#F05454','#30475E','#222831','#DDDDDD'])
plt.title("Composition of Category for Sales")

plt.show()

# %% [markdown]
# # Continue to plotly file
